# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.style

matplotlib.style.use('~/publication.mplstyle')
matplotlib.style.available
plt.rcParams['axes.grid'] = False

# %%
massratio = np.loadtxt('NSBH_mass_ratio.dat')

# %%
print(massratio)
# Out:
# [2.9317303  3.07744329 6.47924576 ... 3.1786894  3.14892218 2.92630598]

# %%
sns.kdeplot(x=massratio,fill=True)
plt.xlim(0,14)

plt.xlabel(r'$1/q$')
# Note that technically I think this is a probably of detection by the LVK; e.g no yr^-1 Mpc^-3. 
plt.ylabel(r'$p(1/q)$')

plt.savefig('NSBH_mass_ratio_density.pdf',dpi=500,bbox_inches='tight')
